# %% [markdown]
# # 1 SciNet Primary Table
# - based on Microsoft Academic Graph (MAG)
# - About MAG: https://www.microsoft.com/en-us/research/project/microsoft-academic-graph/
# - Data Schema: https://docs.microsoft.com/en-us/academic-services/graph/reference-data-schema
# - Also check our data descriptor.

# %%
# %%time
import pandas as pd
SciNet_Papers = pd.read_csv("SciNet_Papers_V0-1.csv", sep="\t")
SciNet_Papers
# MAGID: MAG Paper ID.
# Please check our data descriptor for detailed info of data fields in this table.
# Out:
# CPU times: user 3min 19s, sys: 51.2 s, total: 4min 10s
# Wall time: 4min 12s
#                 MAGID                               DOI     DocType    Year  \
# 0             2789336                               NaN     Journal  2008.0
# 1             9552966                               NaN     Journal  2005.0
# 2             9694411                               NaN  Conference  1994.0
# 3            14355006                               NaN  Repository  2011.0
# 4            14558443      10.1007/978-3-662-45174-8_28  Conference  2014.0
# ...               ...                               ...         ...     ...
# 134129183  3215499129  10.1109/ICRERA52334.2021.9598593         NaN  2021.0
# 134129184  3215845741          10.3389/FCVM.2021.766676     Journal  2021.0
# 134129185  3216186450       10.1016/J.IDNOW.2021.11.004         NaN  2021.0
# 134129186  3216762448      10.1016/J.ISTRUC.2021.10.095     Journal  2022.0
# 134129187  3217727977     10.1109/MLISE54096.2021.00043  Conference  2021.0
#
#                  Date           JID       ConfSID     ConfInsID  C_all   C10  \
# 0          2008-01-01  2.048520e+08           NaN           NaN    1.0   1.0
# 1          2005-05-01  2.737569e+09           NaN           NaN    0.0   0.0
# 2          1994-01-01           NaN  2.755927e+09           NaN    0.0   0.0
# 3          2011-01-01  3.121261e+09           NaN           NaN    0.0   0.0
# 4          2014-10-12           NaN  1.131603e+09  4.038532e+06   14.0  14.0
# ...               ...           ...           ...           ...    ...   ...
# 134129183  2021-09-26           NaN           NaN           NaN    0.0   0.0
# 134129184  2021-11-24  2.595414e+09           NaN           NaN    0.0   0.0
# 134129185  2021-11-24           NaN           NaN           NaN    0.0   0.0
# 134129186  2022-01-01  2.898443e+09           NaN           NaN    0.0   0.0
# 134129187  2021-07-09           NaN  1.180663e+09  3.117406e+09    0.0   0.0
#
#               R   C3   C5  NIH_count  Patent_count  Newsfeed_count  \
# 0          13.0  1.0  1.0        NaN           NaN             NaN
# 1          37.0  0.0  0.0        NaN           NaN             NaN
# 2           0.0  0.0  0.0        NaN           NaN             NaN
# 3           0.0  0.0  0.0        NaN           NaN             NaN
# 4          11.0  6.0  9.0        NaN           NaN             NaN
# ...         ...  ...  ...        ...           ...             ...
# 134129183  14.0  0.0  0.0        NaN           NaN             NaN
# 134129184  33.0  0.0  0.0        NaN           NaN             NaN
# 134129185   0.0  0.0  0.0        NaN           NaN             NaN
# 134129186  33.0  0.0  0.0        NaN           NaN             NaN
# 134129187   0.0  0.0  0.0        NaN           NaN             NaN
#
#            Twitter_count  NCT_count
# 0                    NaN        NaN
# 1                    NaN        NaN
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4                    NaN        NaN
# ...                  ...        ...
# 134129183            NaN        NaN
# 134129184            NaN        NaN
# 134129185            NaN        NaN
# 134129186            NaN        NaN
# 134129187            NaN        NaN
#
# [134129188 rows x 18 columns]

# %% [markdown]
# # 2 Link MAG Paper to Clinical Trials
# - Clinical Trial data schema is here https://aact.ctti-clinicaltrials.org/schema.
# - Clinical Trial data dictionary is here https://aact.ctti-clinicaltrials.org/data_dictionary

# %%
# %%time
import pandas as pd
Link_MAG_PMID_NCTID_ACCT = pd.read_csv("Link_MAG_PMID_NCTID_ACCT.csv", sep="\t")
Link_MAG_PMID_NCTID_ACCT
# MAGID: MAG Paper ID.
# PMID: PubMedID.
# NCT_ID: The National Clinical Trial number.
# Out:
# CPU times: user 204 ms, sys: 9.47 ms, total: 213 ms
# Wall time: 302 ms
#              MAGID      PMID       NCT_ID
# 0             5825  23592934  NCT00486187
# 1            12687  10710805  NCT01402011
# 2            12687  10710805  NCT00685880
# 3            12687  10710805  NCT00085722
# 4            12687  10710805  NCT03515720
# ...            ...       ...          ...
# 438215  2110179408  10998730  NCT02487966
# 438216  3156434758  33871579  NCT05035277
# 438217  2054020285   6387488  NCT00089414
# 438218  2406368488   7091625  NCT04750486
# 438219  2049932300  10332025  NCT01358110
#
# [438220 rows x 3 columns]

# %% [markdown]
# # 3 Link MAG Paper to Patents
# - Data schema of paper-patent linkage: https://zenodo.org/record/5803985.
# - USPTO PatentsView data table: https://patentsview.org/download/data-download-tables
# - USPTO PatentsView data dictionary: https://patentsview.org/download/data-download-dictionary

# %%
# %%time
import pandas as pd
Link_MAG_Patent = pd.read_csv("Link_MAG_Patent.csv", sep="\t")
Link_MAG_Patent
# patent: check the details of https://zenodo.org/record/5803985 for the patent format.
# Out:
# CPU times: user 21.8 s, sys: 2.57 s, total: 24.3 s
# Wall time: 25.2 s
#                MAGID         patent
# 0          183958795  EP-2667337-A3
# 1          855255571     US-9984683
# 2          855255571    US-10595727
# 3          855255571    US-10417788
# 4          855255571    US-10402700
# ...              ...            ...
# 38740308   143872045     US-6372744
# 38740309   143872045     US-6117896
# 38740310  2923798484     US-8038457
# 38740311  2923798484     US-7909635
# 38740312  2923798484     US-7854620
#
# [38740313 rows x 2 columns]

# %% [markdown]
# # 4 Link MAG Paper to Newsfeed
# - detailed info: https://www.eventdata.crossref.org/guide/sources/newsfeed/

# %%
# %%time
import pandas as pd
Link_MAG_Newsfeed = pd.read_csv("Link_MAG_Newsfeed.csv", sep="\t")
Link_MAG_Newsfeed
# obj_id: DOI https link.
# subj_id: News web link.
# Out:
# CPU times: user 1.24 s, sys: 138 ms, total: 1.38 s
# Wall time: 1.44 s
#              MAGID                                      obj_id  \
# 0       2604293429         https://doi.org/10.1038/nature21680
# 1       2604934333     https://doi.org/10.1073/pnas.1619013114
# 2       2604934333     https://doi.org/10.1073/pnas.1619013114
# 3       2081225124         https://doi.org/10.1038/nature13422
# 4       2081225124         https://doi.org/10.1038/nature13422
# ...            ...                                         ...
# 899318  3212058632   https://doi.org/10.1016/j.cub.2021.10.063
# 899319  3128761396  https://doi.org/10.1016/j.cell.2021.01.047
# 899320  3212511064     https://doi.org/10.1073/pnas.2100575118
# 899321  3128699789  https://doi.org/10.1016/j.cell.2021.01.003
# 899322  2733567627        https://doi.org/10.1029/2017EO076589
#
#                                                   subj_id
# 0       https://www.sciencenews.org/article/massive-re...
# 1       https://www.zmescience.com/science/news-scienc...
# 2       https://www.theguardian.com/science/2017/apr/0...
# 3       https://www.zmescience.com/science/news-scienc...
# 4       http://theconversation.com/buried-tools-and-pi...
# ...                                                   ...
# 899318  https://www.quantamagazine.org/flying-fish-and...
# 899319  https://www.quantamagazine.org/flying-fish-and...
# 899320  https://www.quantamagazine.org/flying-fish-and...
# 899321  https://www.quantamagazine.org/flying-fish-and...
# 899322  https://www.sciencealert.com/a-scientist-expla...
#
# [899323 rows x 3 columns]

# %% [markdown]
# # 5 Link MAG Paper to Twitter
# - detailed info: https://www.eventdata.crossref.org/guide/sources/twitter/

# %%
# %%time
import pandas as pd
Link_MAG_Twitter = pd.read_csv("Link_MAG_Twitter.csv", sep="\t")
Link_MAG_Twitter
# obj_id: DOI https link.
# subj_id: Twitter web link or Twitter ID.
# Out:
# CPU times: user 1min 13s, sys: 9.43 s, total: 1min 23s
# Wall time: 1min 23s
#                MAGID                                          obj_id  \
# 0         2409185502          https://doi.org/10.1098/rspb.2016.0792
# 1         2409185502          https://doi.org/10.1098/rspb.2016.0792
# 2         2409185502          https://doi.org/10.1098/rspb.2016.0792
# 3         2409185502          https://doi.org/10.1098/rspb.2016.0792
# 4         2409185502          https://doi.org/10.1098/rspb.2016.0792
# ...              ...                                             ...
# 56121130  2083997846        https://doi.org/10.1177/1098612x15572970
# 56121131  2807381522   https://doi.org/10.1088/0256-307X/35/6/067301
# 56121132  2108824353    https://doi.org/10.1371/journal.pone.0090001
# 56121133  3037760641   https://doi.org/10.1080/00295450.2020.1747837
# 56121134  1990647126  https://doi.org/10.1080/01621459.1975.10480264
#
#                                                     subj_id
# 0         http://twitter.com/PaulKiem/statuses/832519346...
# 1         http://twitter.com/ImmaBioloG/statuses/8331188...
# 2         http://twitter.com/BitKblog/statuses/834133155...
# 3         http://twitter.com/chiara_ceci/statuses/834359...
# 4         http://twitter.com/KLA2010/statuses/8343620020...
# ...                                                     ...
# 56121130            twitter://status?id=1482878777617227776
# 56121131            twitter://status?id=1482888062334283778
# 56121132            twitter://status?id=1482949199104995329
# 56121133            twitter://status?id=1482897388716978177
# 56121134            twitter://status?id=1482914613435977734
#
# [56121135 rows x 3 columns]

# %% [markdown]
# # 6 Link MAG Paper to NIH grants
# - NIH dictionary: https://exporter.nih.gov/about.aspx

# %%
# %%time
import pandas as pd
Link_MAG_PMID_NIHproj = pd.read_csv("Link_MAG_PMID_NIHproj.csv", sep="\t")
Link_MAG_PMID_NIHproj
# PMID: PubMedID.
# PROJECT_NUMBER: NIH Core_Project_Num (which may appear in the acknowledgement part of a paper).
# Out:
# CPU times: user 2.69 s, sys: 256 ms, total: 2.95 s
# Wall time: 2.98 s
#               MAGID      PMID PROJECT_NUMBER
# 0              3066   9923457    R29HL057675
# 1              3066   9923457    R01HL057675
# 2              3066   9923457    R01HL054973
# 3             15845  17127250    P01HD030367
# 4             15845  17127250    M01RR000056
# ...             ...       ...            ...
# 6019894   246319838  12432827    R01NS038713
# 6019895  2082844918  12958435    R01MH061138
# 6019896  2082844918  12958435    R01NS038894
# 6019897  2069345940  11758118    P01AR038923
# 6019898  2069345940  11758118    K08AR002141
#
# [6019899 rows x 3 columns]

# %% [markdown]
# # 7 SciNet Additional Infomation

# %% [markdown]
# - Paper-Lv0Field linakge
# - Check https://docs.microsoft.com/en-us/academic-services/graph/reference-data-schema#paper-fields-of-study

# %%
# %%time
import pandas as pd
SciNet_Paper_LV0Field = pd.read_csv("SciNet_Paper_LV0Field.csv", sep="\t")
SciNet_Paper_LV0Field
# 0: MAGID
# 1: FieldID
# 2: Confidence Score.
# Please also refer to https://docs.microsoft.com/en-us/academic-services/graph/reference-data-schema#paper-fields-of-study
# Out:
# CPU times: user 28.8 s, sys: 5.56 s, total: 34.3 s
# Wall time: 34.4 s
#                     0          1         2
# 0            18936224   71924100  0.304275
# 1            94748468  144024400  0.450289
# 2           113998959   71924100  0.284752
# 3            56740461  144133560  0.432024
# 4                  23   71924100  0.443839
# ...               ...        ...       ...
# 116942136  3204507145   41008148  0.461706
# 116942137  3204507150  185592680  0.387695
# 116942138  3204507160   71924100  0.432389
# 116942139  3204507164   71924100  0.369905
# 116942140  3204507171  144133560  0.443296
#
# [116942141 rows x 3 columns]

# %% [markdown]
# #  8 MAG Additional Infomation

# %%
# Original MAG Files

# %% [markdown]
# ## 8.1 MAG Fields Metadata
# ### Please also check https://docs.microsoft.com/en-us/academic-services/graph/reference-data-schema#fields-of-study.
# ### There is a left shift from column 1 to 10 in the origin data schema to MAG actual data table 0-9 as follows.

# %%
# %%time
import csv
import pandas as pd

df_MAG_F = pd.read_csv('MAG_2021-12-06/FieldsOfStudy.txt', sep='\t', header=None, 
                     quoting=csv.QUOTE_NONE)

df_MAG_F

# Column 5 here is the level of fields ranging from 0 to 5.
# Lv0 field can be considered as the main field.
# Lv1 field can be considered as the sub-field.
# Out:
# CPU times: user 1.41 s, sys: 122 ms, total: 1.53 s
# Wall time: 1.58 s
#                  0      1                          2  \
# 0           417682  16941                  night air
# 1          1443462  16012                immobiliser
# 2          1576492  12988              matrix pencil
# 3          2657588  13563     combinatorial topology
# 4          3079626   8615    quantum electrodynamics
# ...            ...    ...                        ...
# 714966  3020516982  15210           cholesterol diet
# 714967  3020525681  16911    community connectedness
# 714968  3020532668  14800                pre cooling
# 714969  3020562556  14742  image guided radiotherapy
# 714970  3020702029  15527             short implants
#
#                                 3    4  5       6       7        8           9
# 0                       Night air  NaN  2     104     103      428  2016-06-24
# 1                     Immobiliser  NaN  2     220     215     1028  2016-06-24
# 2                   Matrix pencil  NaN  3    1855    1803    30181  2016-06-24
# 3          Combinatorial topology  NaN  3     571     534    22755  2016-06-24
# 4         Quantum electrodynamics  NaN  1  237527  229050  3186718  2016-06-24
# ...                           ...  ... ..     ...     ...      ...         ...
# 714966           Cholesterol diet  NaN  3     559     557     4074  2020-05-01
# 714967    Community connectedness  NaN  3     116     116      718  2020-05-01
# 714968                Pre cooling  NaN  2    1082    1070     2749  2020-05-01
# 714969  Image guided radiotherapy  NaN  4     929     924     6650  2020-05-01
# 714970             Short implants  NaN  3     384     382     3672  2020-05-01
#
# [714971 rows x 10 columns]

# %%
# Have a look at Lv0 field
df_MAG_Lv0_Field = df_MAG_F.loc[df_MAG_F[5] == 0, :]
df_MAG_Lv0_Field
# Out:
#                 0     1                      2                      3  \
# 17405    95457728  6857                history                History
# 23106   127313418  5739                geology                Geology
# 66244   162324750  6154              economics              Economics
# 140540  205649164  6309              geography              Geography
# 203361  185592680  4361              chemistry              Chemistry
# 223318  138885662  7302             philosophy             Philosophy
# 234746  144024400  6131              sociology              Sociology
# 234806  192562407  4156      materials science      Materials science
# 263208   33923547  5140            mathematics            Mathematics
# 286322   86803240  4437                biology                Biology
# 394647   41008148  4251       computer science       Computer science
# 429091   17744445  6005      political science      Political science
# 440715  127413603  4888            engineering            Engineering
# 483247   15744967  5210             psychology             Psychology
# 503185   39432304  5851  environmental science  Environmental science
# 528827  144133560  6097               business               Business
# 617770  121332964  5145                physics                Physics
# 629204   71924100  4136               medicine               Medicine
# 634823  142362112  6780                    art                    Art
#
#                                      4  5         6         7          8  \
# 17405                              NaN  0   3143025   3137420    7840866
# 23106                              NaN  0   7516301   7423997   41596948
# 66244                              NaN  0   3225914   2983588   37661082
# 140540                             NaN  0   4661106   4638221   22960849
# 203361                             NaN  0  18891552  18068928  259797539
# 223318                             NaN  0   2061046   2056029    5004823
# 234746                             NaN  0   4649768   4627492   31643741
# 234806                             NaN  0  31723338  30270466  187946976
# 263208                             NaN  0   7209301   6892438   87228870
# 286322                             NaN  0  14185132  14086624  353707121
# 394647                             NaN  0  28041663  26823800  165506648
# 429091                             NaN  0   7044904   6975783   23127674
# 440715               business.industry  0  12741382  12460293   85771475
# 483247                             NaN  0   8534386   8483915  121799773
# 503185                             NaN  0   6497294   6423665   39668147
# 528827                             NaN  0   5698278   5557415   28479336
# 617770                             NaN  0   9436797   8931911   94882473
# 629204               business.industry  0  30029680  29845676  325547731
# 634823  media_common.quotation_subject  0   3922496   3917328    5147459
#
#                  9
# 17405   2016-06-24
# 23106   2016-06-24
# 66244   2016-06-24
# 140540  2016-06-24
# 203361  2016-06-24
# 223318  2016-06-24
# 234746  2016-06-24
# 234806  2016-06-24
# 263208  2016-06-24
# 286322  2016-06-24
# 394647  2016-06-24
# 429091  2016-06-24
# 440715  2016-06-24
# 483247  2016-06-24
# 503185  2016-06-24
# 528827  2016-06-24
# 617770  2016-06-24
# 629204  2016-06-24
# 634823  2016-06-24

# %% [markdown]
# ## 8.2 MAG Journals Metadata
# ### https://docs.microsoft.com/en-us/academic-services/graph/reference-data-schema#journals

# %%
# %%time
import csv
import pandas as pd

df_MAG_J = pd.read_csv('MAG_2021-12-06/Journals.txt', sep='\t', header=None, 
                     quoting=csv.QUOTE_NONE)

df_MAG_J
# Out:
# CPU times: user 131 ms, sys: 25.2 ms, total: 156 ms
# Wall time: 207 ms
#                0      1                                                  2   \
# 0          465895  12063                                             eureka
# 1         1137746  12416             the artist and journal of home culture
# 2         2978343  15328                              cumberland law review
# 3         3010151  14590                 comparative medicine east and west
# 4         3164724   9991                          physiological measurement
# ...           ...    ...                                                ...
# 49061  2765076455  12073  journal of changsha university of science & te...
# 49062  2898398052  14394                                 reviews in physics
# 49063  2898614270  12482              revista de psiquiatria y salud mental
# 49064  2933375274  13446                   indonesian journal of cardiology
# 49065  3012825557  13101  international journal of occupational and envi...
#
#                                                       3          4   \
# 0                                                 Eureka  1342-5641
# 1                 The Artist and Journal of Home Culture  2329-8189
# 2                                  Cumberland Law Review  0360-8298
# 3                     Comparative Medicine East and West  0147-2917
# 4                              Physiological Measurement  0967-3334
# ...                                                  ...        ...
# 49061  Journal of Changsha University of Science & Te...        NaN
# 49062                                 Reviews in Physics  2405-4283
# 49063              Revista de Psiquiatría y Salud Mental  1888-9891
# 49064                   Indonesian Journal of Cardiology  0126-3773
# 49065  International Journal of Occupational and Envi...  2008-6520
#
#                                  5   \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 49061                           NaN
# 49062                           NaN
# 49063                           NaN
# 49064  Indonesian Heart Association
# 49065      NIOC Health Organization
#
#                                                       6     7     8      9   \
# 0                       http://www.archim.org.uk/eureka/  1150  1150   3149
# 1                                                    NaN   880   880    775
# 2                    http://www.cumberlandlawreview.com/    50    50     58
# 3                                                    NaN    32    32    310
# 4                                                    NaN  3607  3607  88840
# ...                                                  ...   ...   ...    ...
# 49061                                                NaN  1635  1635    161
# 49062  https://www.journals.elsevier.com/reviews-in-p...    49    49   1355
# 49063  https://www.journals.elsevier.com/revista-de-p...   851   851   4895
# 49064                  http://ijconline.id/index.php/ijc   412   412     55
# 49065  https://www.theijoem.com/ijoem/index.php/ijoem...   349   349   3263
#
#                10
# 0      2016-06-24
# 1      2016-06-24
# 2      2016-06-24
# 3      2016-06-24
# 4      2016-06-24
# ...           ...
# 49061  2017-10-27
# 49062  2018-11-02
# 49063  2018-11-02
# 49064  2019-04-11
# 49065  2020-03-27
#
# [49066 rows x 11 columns]

# %% [markdown]
# # 9 Basic Operation Example

# %% [markdown]
# - If we are currently interested in the distribution of physics papers published from 1990 to 2000 according to the number of citations they receive, then

# %%
# %%time
SciNet_Papers_Sel = SciNet_Papers.loc[(SciNet_Papers['Year'] >= 1990) & (SciNet_Papers['Year'] <= 2000), :]
SciNet_Papers_Sel
# Select papers published from 1990 to 2000.
# Out:
# CPU times: user 5.79 s, sys: 7.21 s, total: 13 s
# Wall time: 13 s
#                 MAGID                      DOI      DocType    Year  \
# 2             9694411                      NaN   Conference  1994.0
# 9            23032558                      NaN      Journal  1997.0
# 15           35428871  10.1023/A:1022270923160      Journal  1998.0
# 32           72557836                      NaN   Repository  1996.0
# 41          101311581      10.5070/M3271014515      Journal  1998.0
# ...               ...                      ...          ...     ...
# 134129082  3146715096                      NaN      Journal  1993.0
# 134129083  3148693152                      NaN      Journal  1995.0
# 134129151  3125884817                      NaN   Repository  1993.0
# 134129166  3207562977                      NaN  BookChapter  1990.0
# 134129174  3211627098                      NaN      Journal  2000.0
#
#                  Date           JID       ConfSID  ConfInsID  C_all   C10  \
# 2          1994-01-01           NaN  2.755927e+09        NaN    0.0   0.0
# 9          1997-10-01  2.755314e+09           NaN        NaN    4.0   3.0
# 15         1998-01-01  2.016092e+08           NaN        NaN    6.0   2.0
# 32         1996-01-01  3.121261e+09           NaN        NaN    0.0   0.0
# 41         1998-01-01  1.433928e+08           NaN        NaN    0.0   0.0
# ...               ...           ...           ...        ...    ...   ...
# 134129082  1993-01-01  1.162512e+08           NaN        NaN    0.0   0.0
# 134129083  1995-03-15  1.324228e+07           NaN        NaN    2.0   0.0
# 134129151  1993-01-01  3.121261e+09           NaN        NaN   38.0  20.0
# 134129166  1990-01-01           NaN           NaN        NaN    0.0   0.0
# 134129174  2000-01-01  1.004905e+09           NaN        NaN    0.0   0.0
#
#               R   C3    C5  NIH_count  Patent_count  Newsfeed_count  \
# 2           0.0  0.0   0.0        NaN           NaN             NaN
# 9           0.0  0.0   1.0        NaN           NaN             NaN
# 15         16.0  0.0   0.0        NaN           NaN             NaN
# 32          0.0  0.0   0.0        NaN           NaN             NaN
# 41          0.0  0.0   0.0        NaN           NaN             NaN
# ...         ...  ...   ...        ...           ...             ...
# 134129082   0.0  0.0   0.0        NaN           NaN             NaN
# 134129083   0.0  0.0   0.0        NaN           NaN             NaN
# 134129151   0.0  7.0  13.0        NaN           NaN             NaN
# 134129166   0.0  0.0   0.0        NaN           NaN             NaN
# 134129174   0.0  0.0   0.0        NaN           NaN             NaN
#
#            Twitter_count  NCT_count
# 2                    NaN        NaN
# 9                    NaN        NaN
# 15                   NaN        NaN
# 32                   NaN        NaN
# 41                   NaN        NaN
# ...                  ...        ...
# 134129082            NaN        NaN
# 134129083            NaN        NaN
# 134129151            NaN        NaN
# 134129166            NaN        NaN
# 134129174            NaN        NaN
#
# [16822757 rows x 18 columns]

# %%
# Please note that all data index in Original MAG are int format as 3 below.
df_MAG_Lv0_Field[df_MAG_Lv0_Field[3] == 'Physics']
# As we find out the field ID of physics is 121332964.
# Out:
#                 0     1        2        3    4  5        6        7         8  \
# 617770  121332964  5145  physics  Physics  NaN  0  9436797  8931911  94882473
#
#                  9
# 617770  2016-06-24

# %%
# %%time
# Select physics papers from SciNet_Paper_LV0Field table.
# Please note that all data index in SciNet are string format as '1' below.
Physics_Paper = SciNet_Paper_LV0Field.loc[SciNet_Paper_LV0Field['1'] == 121332964, :]
Physics_Paper
# Out:
# CPU times: user 879 ms, sys: 644 ms, total: 1.52 s
# Wall time: 1.52 s
#                     0          1         2
# 13           38064030  121332964  0.408722
# 29          132789625  121332964  0.427921
# 61          170361713  121332964  0.331290
# 62           56740737  121332964  0.288023
# 98          208270992  121332964  0.396003
# ...               ...        ...       ...
# 116942077  3204506570  121332964  0.399821
# 116942079  3204506608  121332964  0.396794
# 116942082  3204506667  121332964  0.373935
# 116942111  3204506902  121332964  0.320623
# 116942133  3204507122  121332964  0.431623
#
# [5153365 rows x 3 columns]

# %%
# %%time
# Finally select papers published from 1990 to 2000 that appear in the physics paper table.
# It is the DataFrame for physics papers from 1990 to 2000.
SciNet_Physics_Papers_1990_2000 = SciNet_Papers_Sel.loc[SciNet_Papers_Sel['MAGID'].isin(Physics_Paper['0']), :]
SciNet_Physics_Papers_1990_2000
# Out:
# CPU times: user 1.96 s, sys: 260 ms, total: 2.22 s
# Wall time: 2.22 s
#                 MAGID                           DOI     DocType    Year  \
# 15           35428871       10.1023/A:1022270923160     Journal  1998.0
# 145         594551147                           NaN     Journal  1990.0
# 302        1503273383     10.1103/PHYSREVA.53.R3713     Journal  1996.0
# 462        1541102892            10.1007/BF03053644         NaN  1995.0
# 540        1564681818       10.1023/A:1003633413004     Journal  2000.0
# ...               ...                           ...         ...     ...
# 134128374  2532272264      10.1109/PESC.1990.131232  Conference  1990.0
# 134128379  2545668174      10.1109/EQEC.1994.698170  Conference  1994.0
# 134128428    31720894  10.1007/978-94-015-8971-0_20         NaN  1997.0
# 134128655   175040215            10.1007/BF00793898     Journal  1993.0
# 134128758   246752543                           NaN     Journal  1991.0
#
#                  Date          JID       ConfSID  ConfInsID  C_all   C10  \
# 15         1998-01-01  201609156.0           NaN        NaN    6.0   2.0
# 145        1990-03-28    8293853.0           NaN        NaN    0.0   0.0
# 302        1996-06-01  164566984.0           NaN        NaN   27.0  16.0
# 462        1995-02-01          NaN           NaN        NaN   21.0  21.0
# 540        2000-07-01  194044894.0           NaN        NaN   12.0   8.0
# ...               ...          ...           ...        ...    ...   ...
# 134128374  1990-06-11          NaN  2.624178e+09        NaN   13.0   8.0
# 134128379  1994-08-29          NaN  2.755266e+09        NaN    0.0   0.0
# 134128428  1997-01-01          NaN           NaN        NaN    1.0   0.0
# 134128655  1993-04-01   76739556.0           NaN        NaN   20.0   3.0
# 134128758  1991-01-01   98563347.0           NaN        NaN    2.0   1.0
#
#               R   C3   C5  NIH_count  Patent_count  Newsfeed_count  \
# 15         16.0  0.0  0.0        NaN           NaN             NaN
# 145         0.0  0.0  0.0        NaN           NaN             NaN
# 302         0.0  5.0  6.0        NaN           NaN             NaN
# 462         5.0  4.0  4.0        NaN           NaN             NaN
# 540        11.0  1.0  4.0        NaN           NaN             NaN
# ...         ...  ...  ...        ...           ...             ...
# 134128374   3.0  4.0  6.0        NaN           NaN             NaN
# 134128379   0.0  0.0  0.0        NaN           NaN             NaN
# 134128428  10.0  0.0  0.0        NaN           NaN             NaN
# 134128655  14.0  2.0  2.0        NaN           NaN             NaN
# 134128758   0.0  0.0  0.0        NaN           NaN             NaN
#
#            Twitter_count  NCT_count
# 15                   NaN        NaN
# 145                  NaN        NaN
# 302                  NaN        NaN
# 462                  NaN        NaN
# 540                  NaN        NaN
# ...                  ...        ...
# 134128374            NaN        NaN
# 134128379            NaN        NaN
# 134128428            NaN        NaN
# 134128655            NaN        NaN
# 134128758            NaN        NaN
#
# [817198 rows x 18 columns]

# %%
# %%time
# As we focus on the distribution of papers according to their citations, 
# we can extract group by citaiton and aggregate the number of papers fo each group.
Citation_cnt = SciNet_Physics_Papers_1990_2000.groupby(
    ['C_all'], as_index=False)['MAGID'].agg(['count']).reset_index().sort_values(['C_all'], ascending=True)
Citation_cnt
# Out:
# CPU times: user 22.5 ms, sys: 2.92 ms, total: 25.4 ms
# Wall time: 24.4 ms
#          C_all   count
# 0          0.0  238777
# 1          1.0   80662
# 2          2.0   53717
# 3          3.0   40189
# 4          4.0   32621
# ...        ...     ...
# 1575   25954.0       1
# 1576   43470.0       1
# 1577   45463.0       1
# 1578   60504.0       1
# 1579  110567.0       1
#
# [1580 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# sty = 'default'
# mpl.style.use(sty)
fig, ax = plt.subplots(figsize=(8,6), dpi=200)
ax.scatter("C_all", "count", data = Citation_cnt, s = 2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('# of citations',fontsize = 12)
ax.set_ylabel('# of papers',fontsize = 12)
# fig.savefig("./Sample-Figure.pdf", bbox_inches='tight')
# It's better if you try LOG-BINNING.
# Out:
# Text(0, 0.5, '# of papers')

# %% [markdown]
# # Please feel free to contact me if you have any questions ; )
